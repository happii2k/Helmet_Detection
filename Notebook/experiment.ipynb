# %%
import os

local_file_path = "/home/harsh/azuredev-6135/Helmet_Detection"
os.chdir(local_file_path)

# %%
os.getcwd()
# Out:
# '/home/harsh/azuredev-6135/Helmet_Detection'

# %%
from src.cloud.azure_blob import AzureBlob
from dotenv import load_dotenv
load_dotenv()
connection_string = os.getenv("CONNECTION_STRING")
azure_blob = AzureBlob(connection_string)
azure_blob.download_from_azure("data", "data")
# Out:
# [2026-02-03 10:41:51,603] INFO | Initiating download from Azure Blob Storage.
# [2026-02-03 10:41:51,668] INFO | Downloading archive.zip
# [2026-02-03 10:42:03,857] INFO | Download completed successfully.

# %%
from zipfile import ZipFile 
file_name = "data/archive.zip"
with ZipFile(file_name, 'r') as zip:
    zip.extractall("data/")

# %%
import subprocess
import sys

subprocess.check_call([sys.executable, "-m", "pip", "install", "opencv-python"])
# Out:
# Collecting opencv-python
#   Using cached opencv_python-4.13.0.90-cp37-abi3-manylinux_2_28_x86_64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=2 in ./venv/lib/python3.12/site-packages (from opencv-python) (2.4.2)
# Using cached opencv_python-4.13.0.90-cp37-abi3-manylinux_2_28_x86_64.whl (72.9 MB)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.13.0.90
# 0

# %%
import cv2
print(cv2.__version__)
# Out:
# 4.13.0

# %%
from src.components.dataset import HelmetDataset
from src.components.transformation import DataTransformation

transform = DataTransformation(train=True)

dataset = HelmetDataset(transform=transform)

img, target = dataset[0]

print(img.shape)
print(target)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 4
#       1 from src.components.dataset import HelmetDataset
#       2 from src.components.transformation import DataTransformation
# ----> 4 transform = DataTransformation(train=True)
#       6 dataset = HelmetDataset(transform=transform)
#       8 img, target = dataset[0]
#
# File ~/azuredev-6135/Helmet_Detection/src/components/transformation.py:13, in DataTransformation.__init__(self, train)
#      11 trans_cfg = config['data_transformation']
#      12 size = trans_cfg['image_size']
# ---> 13 mean = trans_cfg['mean']
#      14 std = trans_cfg['std']
#      16 aug = trans_cfg['augmentation']
#
# KeyError: 'mean'
